# %% [markdown]
# ## Distributed training with Amazon SageMaker
#
# In this notebook we use the SageMaker Python SDK to setup and run a distributed training job.
# SageMaker makes it easy to train models across a cluster containing a large number of machines, without having to explicitly manage those resources.

# %% [markdown]
# **Step 1:** Import essentials packages, start a sagemaker session and specify the bucket name you created in the pre-requsites section of this workshop.

# %%
import os
import time
import numpy as np
import sagemaker

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

bucket_name = 'chuba-ml-bucket'

# %% [markdown]
# **Step 2:** Specify hyperparameters, instance type and number of instances to distribute training to. The `hvd_processes_per_host` corresponds to the number of GPUs per instances.
# For example, if you choose:
# ```
# hvd_instance_type = 'ml.p3.2xlarge'
# hvd_instance_count = 2
# hvd_processes_per_host = 1
# ```
#
# This is spread across 2 instances (or nodes). SageMaker automatically takes care of spinning up these instances and making sure they can communiate with each other.

# %%
hyperparameters = {'epochs': 5, 
                   'learning-rate': 0.001,
                   'momentum': 0.9,
                   'weight-decay': 2e-4,
                   'optimizer': 'adam',
                   'batch-size' : 256}

hvd_instance_type = 'ml.p3.2xlarge'
hvd_instance_count = 2
hvd_processes_per_host = 1

print('Distributed training with a total of {} workers'.format(hvd_processes_per_host*hvd_instance_count))
print('{} x {} instances with {} processes per instance'.format(hvd_instance_count, hvd_instance_type, hvd_processes_per_host))
# Out:
# Distributed training with a total of 2 workers
# 2 x ml.p3.2xlarge instances with 1 processes per instance

# %% [markdown]
# **Step 3:** In this cell we create a SageMaker estimator, by providing it with all the information it needs to launch instances and execute training on those instances.
#
# Since we're using horovod for distributed training, we specify `distributions` to mpi which is used by horovod.
#
# In the TensorFlow estimator call, we specify training script under `entry_point` and dependencies under `code`. SageMaker automatically copies these files into a TensorFlow container behind the scenes, and are executed on the training instances.

# %%
from sagemaker.tensorflow import TensorFlow

output_path = 's3://{}/'.format(bucket_name)
job_name = 'sm-dist-{}x{}-workers-'.format(hvd_instance_count, hvd_processes_per_host) + time.strftime('%Y-%m-%d-%H-%M-%S-%j', time.gmtime())
model_dir = output_path + 'tensorboard_logs/' + job_name

distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': hvd_processes_per_host,
                    'custom_mpi_options': '-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none'
                        }
                }

estimator_hvd = TensorFlow(base_job_name='hvd-cifar10-tf',
                       source_dir='code',
                       entry_point='cifar10-multi-gpu-horovod-sagemaker.py', 
                       role=role,
                       framework_version='1.14',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=hvd_instance_count, 
                       train_instance_type=hvd_instance_type,
                       output_path=output_path,
                       model_dir=model_dir,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'dist'}],
                       metric_definitions=[{'Name': 'val_acc', 'Regex': 'val_acc: ([0-9\\.]+)'}],
                       distributions=distributions)

# %% [markdown]
# **Step 4:** Specify dataset locations in Amazon S3 and then call the fit function.

# %%
train_path = 's3://{}/cifar10-dataset/train'.format(bucket_name)
val_path = 's3://{}/cifar10-dataset/validation'.format(bucket_name)
eval_path = 's3://{}/cifar10-dataset/eval/'.format(bucket_name)

estimator_hvd.fit({'train': train_path,'validation': val_path,'eval': eval_path}, 
                  job_name=job_name, wait=False)

# %%
estimator_hvd.attach(training_job_name=job_name)
# Out:
# 2020-01-25 18:03:56 Starting - Starting the training job...
# 2020-01-25 18:03:58 Starting - Launching requested ML instances......
# 2020-01-25 18:05:04 Starting - Preparing the instances for training.........
# 2020-01-25 18:06:36 Downloading - Downloading input data...
# 2020-01-25 18:07:16 Training - Training image download completed. Training in progress./usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# I0125 18:07:21.931048 140472306714368 transport.py:1746] Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# I0125 18:07:22.103075 140472306714368 transport.py:1746] Authentication (publickey) successful!
# WARNING: Logging before flag parsing goes to stderr.
# I0125 18:07:21.726982 140698231908096 transport.py:1746] Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# I0125 18:07:21.864678 140698231908096 transport.py:1746] Authentication (publickey) successful!
# Warning: Permanently added 'algo-2,10.0.225.189' (ECDSA) to the list of known hosts.#015
#  Data for JOB [38615,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-254-114#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [38615,1] App: 0 Process rank: 0 Bound: UNBOUND
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [38615,1] App: 0 Process rank: 1 Bound: N/A
#
#  =============================================================
#  Data for JOB [38615,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-254-114#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [38615,1] App: 0 Process rank: 0 Bound: N/A
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [38615,1] App: 0 Process rank: 1 Bound: UNBOUND
#
#  =============================================================
# --------------------------------------------------------------------------
# WARNING: Open MPI tried to bind a process but failed.  This is a
# warning only; your job will continue, though performance may
# be degraded.
#
#   Local host:        ip-10-0-254-114
#   Application name:  /usr/local/bin/python3.6
#   Error message:     failed to bind memory
#   Location:          rtc_hwloc.c:447
#
# --------------------------------------------------------------------------
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:WARNING: Logging before flag parsing goes to stderr.
# [1,1]<stderr>:W0125 18:07:25.315191 140368518252288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:107: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W0125 18:07:25.315496 140368518252288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:141: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# [1,1]<stderr>:
# [1,0]<stderr>:WARNING: Logging before flag parsing goes to stderr.
# [1,0]<stderr>:W0125 18:07:25.308656 140542868383488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:107: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:25.308953 140542868383488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:141: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:25.423577 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:130: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W0125 18:07:25.445503 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:130: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W0125 18:07:25.423890 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:133: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:25.424037 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:133: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W0125 18:07:25.445761 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:133: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W0125 18:07:25.445904 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:133: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,1]<stderr>:
# [1,1]<stderr>:2020-01-25 18:07:25.461187: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# [1,1]<stderr>:2020-01-25 18:07:25.771398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:25.772483: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3dda4e0 executing computations on platform CUDA. Devices:
# [1,1]<stderr>:2020-01-25 18:07:25.772516: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,1]<stderr>:2020-01-25 18:07:25.790982: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300045000 Hz
# [1,1]<stderr>:2020-01-25 18:07:25.791560: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3e4b710 executing computations on platform Host. Devices:
# [1,1]<stderr>:2020-01-25 18:07:25.791588: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# [1,1]<stderr>:2020-01-25 18:07:25.791895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:25.792944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:2020-01-25 18:07:25.793037: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:25.869766: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:25.906097: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:25.917356: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.004849: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.057698: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.210120: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,1]<stderr>:2020-01-25 18:07:26.210315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.211412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.212330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# [1,1]<stderr>:2020-01-25 18:07:26.212969: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.328286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,1]<stderr>:2020-01-25 18:07:26.328345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# [1,1]<stderr>:2020-01-25 18:07:26.328356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# [1,1]<stderr>:2020-01-25 18:07:26.329377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.330368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.331296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15008 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# [1,1]<stderr>:W0125 18:07:26.359376 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:74: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W0125 18:07:26.359624 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:77: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W0125 18:07:26.429100 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:42: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W0125 18:07:26.418275 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:74: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:26.418536 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:77: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W0125 18:07:26.447679 140368518252288 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:45: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
# [1,1]<stderr>:
# [1,1]<stderr>:2020-01-25 18:07:26.478778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.479769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:2020-01-25 18:07:26.479848: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.479908: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.479940: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.479966: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.479989: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.480014: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:26.480046: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,1]<stderr>:2020-01-25 18:07:26.480110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.481059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2020-01-25 18:07:26.481942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# [1,1]<stderr>:W0125 18:07:26.498359 140368518252288 deprecation.py:323] From cifar10-multi-gpu-horovod-sagemaker.py:63: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# [1,0]<stderr>:W0125 18:07:26.486033 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:42: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:26.506422 140542868383488 deprecation_wrapper.py:119] From cifar10-multi-gpu-horovod-sagemaker.py:45: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W0125 18:07:26.555983 140542868383488 deprecation.py:323] From cifar10-multi-gpu-horovod-sagemaker.py:63: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# [1,1]<stderr>:W0125 18:07:26.693103 140368518252288 deprecation.py:506] From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Call initializer instance with the dtype argument instead of passing it to the constructor
# [1,0]<stderr>:W0125 18:07:26.750352 140542868383488 deprecation.py:506] From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Call initializer instance with the dtype argument instead of passing it to the constructor
# [1,1]<stderr>:W0125 18:07:27.869059 140368518252288 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:81: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Deprecated in favor of operator or tf.math.divide.
# [1,0]<stderr>:W0125 18:07:27.956718 140542868383488 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:81: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Deprecated in favor of operator or tf.math.divide.
# [ip-10-0-254-114.us-west-2.compute.internal:00040] 1 more process has sent help message help-orte-odls-default.txt / memory not bound
# [ip-10-0-254-114.us-west-2.compute.internal:00040] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,1]<stdout>:Epoch 1/5
# [1,0]<stdout>:Epoch 1/5
# [1,1]<stderr>:2020-01-25 18:07:33.614610: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2020-01-25 18:07:34.562586: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.254.114<0>
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:46:57 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.225.189<0>
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,1]<stdout>:
# [1,1]<stdout>:algo-2:52:63 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Setting affinity for GPU 0 to ff
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Setting affinity for GPU 0 to ff
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Duplicating rings to 4 per user request.
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Channel 00 :    0   1
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Channel 01 :    0   1
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Channel 02 :    0   1
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Channel 03 :    0   1
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 00 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 00 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 00 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 00 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 01 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 01 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 01 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 01 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 02 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 02 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 02 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 02 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 03 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 03 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Ring 03 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO Ring 03 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees disabled
# [1,1]<stdout>:algo-2:52:63 [0] NCCL INFO comm 0x7fa9a4394990 rank 1 nranks 2 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO comm 0x7fd23c2fceb0 rank 0 nranks 2 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,0]<stdout>:algo-1:46:57 [0] NCCL INFO Launch mode Parallel
# [1,0]<stdout>:#015[1,0]<stdout>: 1/78 [..............................] - ETA: 7:03 - loss: 3.6994 - acc: 0.1211[1,1]<stdout>:#015[1,1]<stdout>: 1/78 [..............................] - ETA: 7:04 - loss: 3.8987 - acc: 0.1055[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 3/78 [>.............................] - ETA: 2:20 - loss: 3.6204 - acc: 0.1198[1,1]<stdout>: 3/78 [>.............................] - ETA: 2:21 - loss: 3.7908 - acc: 0.1172[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 4/78 [>.............................] - ETA: 1:46 - loss: 3.5600 - acc: 0.1152[1,1]<stdout>: 4/78 [>.............................] - ETA: 1:46 - loss: 3.6504 - acc: 0.1191[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 5/78 [>.............................] - ETA: 1:25 - loss: 3.3584 - acc: 0.1258[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 5/78 [>.............................] - ETA: 1:25 - loss: 3.4746 - acc: 0.1164[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 6/78 [=>............................] - ETA: 1:11 - loss: 3.3201 - acc: 0.1289[1,0]<stdout>: 6/78 [=>............................] - ETA: 1:11 - loss: 3.2373 - acc: 0.1328[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 7/78 [=>..... ...
# #010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:46/78 [================>.............] - ETA: 7s - loss: 2.2436 - acc: 0.2151[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:47/78 [=================>............] - ETA: 6s - loss: 2.2365 - acc: 0.2157[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:47/78 [=================>............] - ETA: 6s - loss: 2.2198 - acc: 0.2148[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:48/78 [=================>............] - ETA: 6s - loss: 2.2283 - acc: 0.2170[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:48/78 [=================>............] - ETA: 6s - loss: 2.2116 - acc: 0.2162[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:49/78 [=================>............] - ETA: 6s - loss: 2.2225 - acc: 0.2180[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:49/78 [=================>............] - ETA: 6s - loss: 2.2049 - acc: 0.2182[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:50/78 [==================>...........] - ETA: 6s - loss: 2.2150 - acc: 0.2195[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:50/78 [==================>...........] - ETA: 6s - loss: 2.1984 - acc: 0.2189[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:51/78 [==================>...........] - ETA: 5s - loss: 2.2088 - acc: 0.2195[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# [1,1]<stdout>:Epoch 2/5
# [1,0]<stdout>:Completed 256.0 KiB/961.2 KiB (13.2 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 512.0 KiB/961.2 KiB (23.5 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 768.0 KiB/961.2 KiB (32.7 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 961.2 KiB/961.2 KiB (7.9 MiB/s) with 1 file(s) remaining #015[1,0]<stdout>:upload: ../output/data/20200125-180726/events.out.tfevents.1579975648.algo-1 to s3://chuba-ml-bucket/tensorboard_logs/sm-dist-2x1-workers-2020-01-25-18-03-56-025/events.out.tfevents.1579975648.algo-1
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:78/78 [==============================] - 20s 251ms/step - loss: 2.0647 - acc: 0.2507 - val_loss: 2.0824 - val_acc: 0.2238
# [1,0]<stdout>:Epoch 2/5
# ...
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:46/78 [================>.............] - ETA: 4s - loss: 1.3630 - acc: 0.4980[1,0]<stdout>:46/78 [================>.............] - ETA: 3s - loss: 1.3605 - acc: 0.5008[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:47/78 [=================>............] - ETA: 4s - loss: 1.3641 - acc: 0.4979[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:47/78 [=================>............] - ETA: 3s - loss: 1.3617 - acc: 0.4997[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:48/78 [=================>............] - ETA: 3s - loss: 1.3635 - acc: 0.4999[1,1]<stdout>:48/78 [=================>............] - ETA: 3s - loss: 1.3651 - acc: 0.4975[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:49/78 [=================>............] - ETA: 3s - loss: 1.3640 - acc: 0.4995[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:49/78 [=================>............] - ETA: 3s - loss: 1.3669 - acc: 0.4966[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:50/78 [==================>...........] - ETA: 2s - loss: 1.3635 - acc: 0.4994[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:50/78 [==================>...........] - ETA: 3s - loss: 1.3661 - acc: 0.4971[1,1]<stdout ...
# [1,1]<stdout>:Epoch 5/5
# [1,0]<stdout>:Completed 256.0 KiB/961.9 KiB (14.9 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 512.0 KiB/961.9 KiB (26.2 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 768.0 KiB/961.9 KiB (35.5 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 961.9 KiB/961.9 KiB (14.0 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:upload: ../output/data/20200125-180726/events.out.tfevents.1579975648.algo-1 to s3://chuba-ml-bucket/tensorboard_logs/sm-dist-2x1-workers-2020-01-25-18-03-56-025/events.out.tfevents.1579975648.algo-1
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:78/78 [==============================] - 11s 147ms/step - loss: 1.3505 - acc: 0.5069 - val_loss: 1.7480 - val_acc: 0.3757
# [1,0]<stdout>:Epoch 5/5
# [1,1]<stdout>:#015[1,1]<stdout>: 1/78 [..............................] - ETA: 1:32 - loss: 1.3005 - acc: 0.5469[1,0]<stdout>:#015[1,0]<stdout>: 1/78 [..............................] - ETA: 1s - loss: 1.3421 - acc: 0.5352[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 2/78 [..............................] - ETA: 4s - loss: 1.3055 - acc: 0.5371[1,1]<stdout>: 2/78 [..............................] - ETA: 49s - loss: 1.2686 - acc: 0.5547 [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 3/78 [>.............................] - ETA: 5s - loss: 1.3006 - acc: 0.5339[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 3/78 [>.............................] - ETA: 35s - loss: 1.3041 - acc: 0.5378[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 4/78 [>.............................] - ETA: 6s - loss: 1.3293 - acc: 0.5303[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 4/78 [>.............................] - ETA: 28s - loss: 1.3121 - acc: 0.5312[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 5/78 [>.............................] - ETA: 6s - loss: 1.3009 - acc: 0.5383[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 5/78 [>.............................] - ETA: 23s - loss: 1.3006 - acc: 0.5398[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 6/78 [=>............................] - ETA: 6s - loss: 1.2823 - acc: 0.5423[1 ...
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:46/78 [================>.............] - ETA: 4s - loss: 1.2790 - acc: 0.5401[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:46/78 [================>.............] - ETA: 3s - loss: 1.2783 - acc: 0.5401[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:47/78 [=================>............] - ETA: 4s - loss: 1.2770 - acc: 0.5404[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:47/78 [=================>............] - ETA: 3s - loss: 1.2772 - acc: 0.5411[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:48/78 [=================>............] - ETA: 3s - loss: 1.2771 - acc: 0.5405[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:48/78 [=================>............] - ETA: 3s - loss: 1.2765 - acc: 0.5409[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:49/78 [=================>............] - ETA: 3s - loss: 1.2754 - acc: 0.5415[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:49/78 [=================>............] - ETA: 3s - loss: 1.2733 - acc: 0.5426[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:50/78 [==================>...........] - ETA: 3s - loss: 1.2749 - acc: 0.5423[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# [1,0]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.002.
# [1,1]<stdout>:
# [1,1]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.002.
# [1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:78/78 [==============================] - 11s 146ms/step - loss: 1.2621 - acc: 0.5491 - val_loss: 1.4382 - val_acc: 0.4955
# [1,0]<stdout>:Completed 256.0 KiB/962.1 KiB (9.5 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 512.0 KiB/962.1 KiB (14.7 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 768.0 KiB/962.1 KiB (18.9 MiB/s) with 1 file(s) remaining#015[1,0]<stdout>:Completed 962.1 KiB/962.1 KiB (9.6 MiB/s) with 1 file(s) remaining #015[1,0]<stdout>:upload: ../output/data/20200125-180726/events.out.tfevents.1579975648.algo-1 to s3://chuba-ml-bucket/tensorboard_logs/sm-dist-2x1-workers-2020-01-25-18-03-56-025/events.out.tfevents.1579975648.algo-1
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:78/78 [==============================] - 11s 147ms/step - loss: 1.2610 - acc: 0.5491 - val_loss: 1.4382 - val_acc: 0.4955
# [1,1]<stdout>:Test loss    : 1.4201113230142839
# [1,1]<stdout>:Test accuracy: 0.5005008
# [1,0]<stdout>:Test loss    : 1.4219011465708415
# [1,0]<stdout>:Test accuracy: 0.5041066
# W0125 18:08:44.141819 140472546375424 training.py:181] No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2020-01-25 18:09:26 Uploading - Uploading generated training model
# 2020-01-25 18:09:26 Completed - Training job completed
# W0125 18:09:14.171159 140698513516288 training.py:181] No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# Training seconds: 340
# Billable seconds: 340

# %% [markdown]
# **Note**: in the `estimator_hvd.fit()` function above, change`wait=True` if you want to see the training output in the Jupyter notebook.
# Advantage of setting `wait=False`, is that you can continue to run cells.
# Since we're unblocked due to `wait=False` we can now launch tensorboard in the notebook and monitor progress.
