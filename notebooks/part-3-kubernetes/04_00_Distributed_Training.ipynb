# %% [markdown]
# # Background
# Deep learning has shown that being able to train large models on vasts amount of data can drastically improve model performance.
#
#
# However, consider the problem of training a deep network with millions, or even billions of parameters. How do we achieve this without waiting for days, or even multiple weeks? Dean et al propose a different training paradigm which allows us to train and serve a model on multiple physical machines. The auth|ors propose two novel methodologies to accomplish this, namely, `model parallelism` and `data parallelism`.
#
#
# ## Model Parallelism
# When a big model can not fit into a single node's memory, model parallel training can be employed to handle the big model. Model parallelism training has two key features:
# 1. Each worker task is responsible for estimating different part of the model parameters. So the computation logic in each worker is different from other one else.
# 2. There is application-level data communication between workers.
#
# ![Model Parallelism](./images/model_parallelism.jpg)
#
#
# ## Data Parallelism
#
# The algorithm distributes the data between various tasks.
# 1. Each worker task is responsible for estimating different part of the dataset
# 2. Tasks then exchange their estimate(s) with each other to come up with the right estimate for the step.
#
# ![Data Parallelism](./images/data_parallelism.png)

# %% [markdown]
# # Distributed Training in Tensorflow
# "Data Parallelism" is the most common training configuration, it involves multiple tasks in a `worker` job training the same model on different mini-batches of data, updating shared parameters hosted in one or more tasks in a `ps` (parameter server) job. All tasks typically run on different machines or containers. There are many ways to specify this structure in TensorFlow, and Tensorflow team are building libraries that will simplify the work of specifying a replicated model. Other platforms like `MXnet`, `Petuum` also have the same abstraction.
#
# - __In-graph replication__. In this approach, the client builds a single tf.Graph that contains one set of parameters (in tf.Variable nodes pinned to /job:ps); and multiple copies of the compute-intensive part of the model, each pinned to a different task in /job:worker.
#
# - __Between-graph replication__. In this approach, there is a separate client for each /job:worker task, typically in the same process as the worker task. Each client builds a similar graph containing the parameters (pinned to /job:ps as before using tf.train.replica_device_setter to map them deterministically to the same tasks); and a single copy of the compute-intensive part of the model, pinned to the local task in /job:worker.
#
# - __Asynchronous training__. In this approach, each replica of the graph has an independent training loop that executes without coordination. It is compatible with both forms of replication above.
#
# - __Synchronous training__. In this approach, all of the replicas read the same values for the current parameters, compute gradients in parallel, and then apply them together. It is compatible with in-graph replication (e.g. using gradient averaging as in the CIFAR-10 multi-GPU trainer), and between-graph replication (e.g. using the tf.train.SyncReplicasOptimizer).

# %% [markdown]
# ## Examples
#
# We will introduce two frameworks in the distributed training. Tensorflow and PyTorch

# %% [markdown]
# ### Tensorflow

# %% [markdown]
# #### Check Tensorflow PS Job

# %%
# !cat ./distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "TFJob"
# metadata:
#   name: "distributed-tensorflow-job"
# spec:
#   tfReplicaSpecs:
#     PS:
#       replicas: 2
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#     Worker:
#       replicas: 4
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0

# %% [markdown]
# #### Submit TFJob distributed training job

# %%
# !kubectl create -f distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# tfjob.kubeflow.org/distributed-tensorflow-job created

# %% [markdown]
# #### Get all TFJobs

# %%
# !kubectl get tfjob
# Out:
# NAME                         STATE     AGE
# distributed-tensorflow-job   Created   3s

# %% [markdown]
# #### Check TFJob Status

# %%
# !kubectl describe tfjob distributed-tensorflow-job
# Out:
# Name:         distributed-tensorflow-job
# Namespace:    eksworkshop
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1
# Kind:         TFJob
# Metadata:
#   Creation Timestamp:  2020-01-25T21:44:16Z
#   Generation:          1
#   Resource Version:    49678
#   Self Link:           /apis/kubeflow.org/v1/namespaces/eksworkshop/tfjobs/distributed-tensorflow-job
#   UID:                 d584767b-3fbb-11ea-9a5c-0a9556c1ecda
# Spec:
#   Tf Replica Specs:
#     PS:
#       Replicas:        2
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
#     Worker:
#       Replicas:        4
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
# Status:
#   Conditions:
#     Last Transition Time:  2020-01-25T21:44:16Z
#     Last Update Time:      2020-01-25T21:44:16Z
#     Message:               TFJob distributed-tensorflow-job is created.
#     Reason:                TFJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     PS:
#     Worker:
#   Start Time:  2020-01-25T21:44:16Z
# Events:
#   Type    Reason                   Age   From         Message
#   ----    ------                   ----  ----         -------
#   Normal  SuccessfulCreatePod      6s    tf-operator  Created pod: distributed-tensorflow-job-worker-0
#   Normal  SuccessfulCreatePod      6s    tf-operator  Created pod: distributed-tensorflow-job-worker-1
#   Normal  SuccessfulCreatePod      6s    tf-operator  Created pod: distributed-tensorflow-job-worker-2
#   Normal  SuccessfulCreatePod      6s    tf-operator  Created pod: distributed-tensorflow-job-worker-3
#   Normal  SuccessfulCreateService  6s    tf-operator  Created service: distributed-tensorflow-job-worker-0
#   Normal  SuccessfulCreateService  6s    tf-operator  Created service: distributed-tensorflow-job-worker-1
#   Normal  SuccessfulCreateService  6s    tf-operator  Created service: distributed-tensorflow-job-worker-2
#   Normal  SuccessfulCreateService  5s    tf-operator  Created service: distributed-tensorflow-job-worker-3
#   Normal  SuccessfulCreatePod      5s    tf-operator  Created pod: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreatePod      5s    tf-operator  Created pod: distributed-tensorflow-job-ps-1
#   Normal  SuccessfulCreateService  4s    tf-operator  Created service: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreateService  4s    tf-operator  Created service: distributed-tensorflow-job-ps-1

# %% [markdown]
# #### Check all the pods created by this TFJob

# %%
# !kubectl get pod | grep distributed-tensorflow-job
# Out:
# distributed-tensorflow-job-ps-0       0/1     ContainerCreating   0          7s
# distributed-tensorflow-job-ps-1       0/1     ContainerCreating   0          7s
# distributed-tensorflow-job-worker-0   0/1     ContainerCreating   0          8s
# distributed-tensorflow-job-worker-1   0/1     ContainerCreating   0          8s
# distributed-tensorflow-job-worker-2   0/1     ContainerCreating   0          8s
# distributed-tensorflow-job-worker-3   0/1     ContainerCreating   0          8s

# %% [markdown]
# #### Check logs of one worker pod
# `-f` means follow and it will block the process until the job finish. If you want to check current logs and return immediately, please run without `-f` or click `Kernel` -> `Interrupt` to stop the process.

# %%
# !kubectl logs -f distributed-tensorflow-job-worker-0
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2020-01-25 21:44:38.312118: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2020-01-25 21:44:38.312854: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> distributed-tensorflow-job-ps-0.eksworkshop.svc:2222, 1 -> distributed-tensorflow-job-ps-1.eksworkshop.svc:2222}
# 2020-01-25 21:44:38.312872: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> localhost:2222, 1 -> distributed-tensorflow-job-worker-1.eksworkshop.svc:2222, 2 -> distributed-tensorflow-job-worker-2.eksworkshop.svc:2222, 3 -> distributed-tensorflow-job-worker-3.eksworkshop.svc:2222}
# 2020-01-25 21:44:38.313251: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# WARNING:tensorflow:From /var/tf_dist_mnist/dist_mnist.py:239: __init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2020-01-25 21:44:38.554324: I tensorflow/core/distributed_runtime/master_session.cc:1017] Start master session 28b362f004cc1b12 with config: device_filters: "/job:ps" device_filters: "/job:worker/task:0" allow_soft_placement: true
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/mnist-data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/mnist-data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/mnist-data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/mnist-data/t10k-labels-idx1-ubyte.gz
# job name = worker
# task index = 0
# Worker 0: Initializing session...
# Worker 0: Session initialization complete.
# Training begins @ 1579988678.715834
# 1579988678.861343: Worker 0: training step 1 done (global step: 0)
# 1579988678.865509: Worker 0: training step 2 done (global step: 1)
# 1579988678.869439: Worker 0: training step 3 done (global step: 2)
# 1579988678.873010: Worker 0: training step 4 done (global step: 3)
# 1579988678.876694: Worker 0: training step 5 done (global step: 4)
# 1579988678.880783: Worker 0: training step 6 done (global step: 5)
# 1579988678.884536: Worker 0: training step 7 done (global step: 6)
# 1579988678.888892: Worker 0: training step 8 done (global step: 7)
# 1579988678.893039: Worker 0: training step 9 done (global step: 8)
# 1579988678.896933: Worker 0: training step 10 done (global step: 9)
# 1579988678.900902: Worker 0: training step 11 done (global step: 10)
# 1579988678.905505: Worker 0: training step 12 done (global step: 11)
# 1579988678.910489: Worker 0: training step 13 done (global step: 13)
# 1579988678.914859: Worker 0: training step 14 done (global step: 15)
# 1579988678.918908: Worker 0: training step 15 done (global step: 17)
# 1579988678.922754: Worker 0: training step 16 done (global step: 18)
# 1579988678.926219: Worker 0: training step 17 done (global step: 20)
# 1579988678.930803: Worker 0: training step 18 done (global step: 22)
# 1579988678.935417: Worker 0: training step 19 done (global step: 24)
# 1579988678.939175: Worker 0: training step 20 done (global step: 25)
# 1579988678.943663: Worker 0: training step 21 done (global step: 27)
# 1579988678.947708: Worker 0: training step 22 done (global step: 29)
# 1579988678.951288: Worker 0: training step 23 done (global step: 31)
# 1579988678.954906: Worker 0: training step 24 done (global step: 33)
# 1579988678.958629: Worker 0: training step 25 done (global step: 34)
# 1579988678.962259: Worker 0: training step 26 done (global step: 36)
# 1579988678.966346: Worker 0: training step 27 done (global step: 38)
# 1579988678.970038: Worker 0: training step 28 done (global step: 40)
# 1579988678.973982: Worker 0: training step 29 done (global step: 42)
# 1579988678.978247: Worker 0: training step 30 done (global step: 43)
# 1579988678.982993: Worker 0: training step 31 done (global step: 45)
# 1579988678.987270: Worker 0: training step 32 done (global step: 47)
# 1579988678.991175: Worker 0: training step 33 done (global step: 49)
# 1579988678.997266: Worker 0: training step 34 done (global step: 51)
# 1579988679.000889: Worker 0: training step 35 done (global step: 53)
# 1579988679.004871: Worker 0: training step 36 done (global step: 55)
# 1579988679.009034: Worker 0: training step 37 done (global step: 56)
# 1579988679.013763: Worker 0: training step 38 done (global step: 58)
# 1579988679.020413: Worker 0: training step 39 done (global step: 60)
# 1579988679.024425: Worker 0: training step 40 done (global step: 63)
# 1579988679.028700: Worker 0: training step 41 done (global step: 65)
# 1579988679.032125: Worker 0: training step 42 done (global step: 67)
# 1579988679.036581: Worker 0: training step 43 done (global step: 68)
# 1579988679.042919: Worker 0: training step 44 done (global step: 70)
# 1579988679.046689: Worker 0: training step 45 done (global step: 73)
# 1579988679.050846: Worker 0: training step 46 done (global step: 74)
# 1579988679.054660: Worker 0: training step 47 done (global step: 76)
# 1579988679.058406: Worker 0: training step 48 done (global step: 78)
# 1579988679.062241: Worker 0: training step 49 done (global step: 80)
# 1579988679.066199: Worker 0: training step 50 done (global step: 81)
# 1579988679.072217: Worker 0: training step 51 done (global step: 83)
# 1579988679.076642: Worker 0: training step 52 done (global step: 85)
# 1579988679.080824: Worker 0: training step 53 done (global step: 87)
# 1579988679.084956: Worker 0: training step 54 done (global step: 89)
# 1579988679.088873: Worker 0: training step 55 done (global step: 90)
# 1579988714.395021: Worker 0: training step 5967 done (global step: 19889)
# 1579988714.401112: Worker 0: training step 5968 done (global step: 19892)
# 1579988714.406716: Worker 0: training step 5969 done (global step: 19894)
# 1579988714.410922: Worker 0: training step 5970 done (global step: 19897)
# 1579988714.416684: Worker 0: training step 5971 done (global step: 19900)
# 1579988714.421557: Worker 0: training step 5972 done (global step: 19903)
# 1579988714.426751: Worker 0: training step 5973 done (global step: 19905)
# 1579988714.432345: Worker 0: training step 5974 done (global step: 19907)
# 1579988714.439858: Worker 0: training step 5975 done (global step: 19910)
# 1579988714.445858: Worker 0: training step 5976 done (global step: 19913)
# 1579988714.450800: Worker 0: training step 5977 done (global step: 19916)
# 1579988714.455941: Worker 0: training step 5978 done (global step: 19919)
# 1579988714.461694: Worker 0: training step 5979 done (global step: 19921)
# 1579988714.466230: Worker 0: training step 5980 done (global step: 19924)
# 1579988714.471629: Worker 0: training step 5981 done (global step: 19926)
# 1579988714.480177: Worker 0: training step 5982 done (global step: 19929)
# 1579988714.488141: Worker 0: training step 5983 done (global step: 19933)
# 1579988714.494478: Worker 0: training step 5984 done (global step: 19937)
# 1579988714.502108: Worker 0: training step 5985 done (global step: 19941)
# 1579988714.506764: Worker 0: training step 5986 done (global step: 19942)
# 1579988714.514388: Worker 0: training step 5987 done (global step: 19946)
# 1579988714.518921: Worker 0: training step 5988 done (global step: 19950)
# 1579988714.525161: Worker 0: training step 5989 done (global step: 19954)
# 1579988714.531285: Worker 0: training step 5990 done (global step: 19958)
# 1579988714.537199: Worker 0: training step 5991 done (global step: 19962)
# 1579988714.541541: Worker 0: training step 5992 done (global step: 19964)
# 1579988714.547252: Worker 0: training step 5993 done (global step: 19968)
# 1579988714.553375: Worker 0: training step 5994 done (global step: 19972)
# 1579988714.558346: Worker 0: training step 5995 done (global step: 19976)
# 1579988714.564868: Worker 0: training step 5996 done (global step: 19978)
# 1579988714.570158: Worker 0: training step 5997 done (global step: 19982)
# 1579988714.575531: Worker 0: training step 5998 done (global step: 19986)
# 1579988714.580318: Worker 0: training step 5999 done (global step: 19989)
# 1579988714.587278: Worker 0: training step 6000 done (global step: 19993)
# 1579988714.594700: Worker 0: training step 6001 done (global step: 19997)
# 1579988714.600199: Worker 0: training step 6002 done (global step: 20001)
# Training ends @ 1579988714.600235
# Training elapsed time: 35.884401 s
# After 20000 training step(s), validation cross entropy = 1590.22

# %% [markdown]
# ### PyTorch

# %%
# !cat ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "PyTorchJob"
# metadata:
#   name: "distributed-pytorch-job"
# spec:
#   pytorchReplicaSpecs:
#     Master:
#       replicas: 1
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1
#     Worker:
#       replicas: 2
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1

# %%
# !kubectl apply -f ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# pytorchjob.kubeflow.org/distributed-pytorch-job created

# %%
# !kubectl describe pytorchjob distributed-pytorch-job
# Out:
# Name:         distributed-pytorch-job
# Namespace:    eksworkshop
# Labels:       <none>
# Annotations:  kubectl.kubernetes.io/last-applied-configuration:
#                 {"apiVersion":"kubeflow.org/v1","kind":"PyTorchJob","metadata":{"annotations":{},"name":"distributed-pytorch-job","namespace":"eksworkshop...
# API Version:  kubeflow.org/v1
# Kind:         PyTorchJob
# Metadata:
#   Creation Timestamp:  2020-01-25T21:45:54Z
#   Generation:          1
#   Resource Version:    50380
#   Self Link:           /apis/kubeflow.org/v1/namespaces/eksworkshop/pytorchjobs/distributed-pytorch-job
#   UID:                 1069d727-3fbc-11ea-9a5c-0a9556c1ecda
# Spec:
#   Pytorch Replica Specs:
#     Master:
#       Replicas:        1
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
#     Worker:
#       Replicas:        2
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
# Status:
#   Conditions:
#     Last Transition Time:  2020-01-25T21:45:55Z
#     Last Update Time:      2020-01-25T21:45:55Z
#     Message:               PyTorchJob distributed-pytorch-job is created.
#     Reason:                PyTorchJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     Master:
#     Worker:
#   Start Time:  2020-01-25T21:45:55Z
# Events:
#   Type    Reason                   Age   From              Message
#   ----    ------                   ----  ----              -------
#   Normal  SuccessfulCreatePod      3s    pytorch-operator  Created pod: distributed-pytorch-job-master-0
#   Normal  SuccessfulCreateService  3s    pytorch-operator  Created service: distributed-pytorch-job-master-0
#   Normal  SuccessfulCreatePod      3s    pytorch-operator  Created pod: distributed-pytorch-job-worker-0
#   Normal  SuccessfulCreatePod      3s    pytorch-operator  Created pod: distributed-pytorch-job-worker-1

# %%
# !kubectl get pod | grep distributed-pytorch-job
# Out:
# distributed-pytorch-job-master-0      0/1     ContainerCreating   0          6s
# distributed-pytorch-job-worker-0      0/1     Init:0/1            0          6s
# distributed-pytorch-job-worker-1      0/1     Init:0/1            0          6s

# %%
# !kubectl logs -f distributed-pytorch-job-master-0
# Out:
# Error from server (BadRequest): container "pytorch" in pod "distributed-pytorch-job-master-0" is waiting to start: ContainerCreating
